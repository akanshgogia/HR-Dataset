# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('HRdataset.csv')
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                   1/3/2019              0       15
# 4                   2/1/2016              0        2
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (311, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
#  13  State                       311 non-null    object
#  14  Zip                         311 non-null    int64
#  15  DOB                         311 non-null    object
#  16  Sex                         311 non-null    object
#  17  MaritalDesc                 311 non-null    object
#  18  CitizenDesc                 311 non-null    object
#  19  HispanicLatino              311 non-null    object
#  20  RaceDesc                    311 non-null    object
#  21  DateofHire                  311 non-null    object
#  22  DateofTermination           104 non-null    object
#  23  TermReason                  311 non-null    object
#  24  EmploymentStatus            311 non-null    object
#  25  Department                  311 non-null    object
#  26  ManagerName                 311 non-null    object
#  27  ManagerID                   303 non-null    float64
#  28  RecruitmentSource           311 non-null    object
#  29  PerformanceScore            311 non-null    object
#  30  EngagementSurvey            311 non-null    float64
#  31  EmpSatisfaction             311 non-null    int64
#  32  SpecialProjectsCount        311 non-null    int64
#  33  LastPerformanceReview_Date  311 non-null    object
#  34  DaysLateLast30              311 non-null    int64
#  35  Absences                    311 non-null    int64
# dtypes: float64(2), int64(16), object(18)
# memory usage: 87.6+ KB

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# RecruitmentSource               0
# PerformanceScore                0
# EngagementSurvey                0
# EmpSatisfaction                 0
# SpecialProjectsCount            0
# LastPerformanceReview_Date      0
# DaysLateLast30                  0
# Absences                        0
# dtype: int64

# %%
df= df.fillna("0")
df= df.dropna()

# %%
df.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# PerformanceScore              0
# EngagementSurvey              0
# EmpSatisfaction               0
# SpecialProjectsCount          0
# LastPerformanceReview_Date    0
# DaysLateLast30                0
# Absences                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
attrition_rate= (df['EmploymentStatus'].value_counts(normalize=True)) * 100
attrition_rate
# Out:
# EmploymentStatus
# Active                    66.559486
# Voluntarily Terminated    28.295820
# Terminated for Cause       5.144695
# Name: proportion, dtype: float64

# %% [markdown]
# # Departments having highest number of emplyees

# %%
df['Department'].value_counts()
# Out:
# Department
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: count, dtype: int64

# %% [markdown]
# ### Interpretation
# * Displays count of employees in each department
# * The department with the highest value = largest workforce

# %% [markdown]
# ### Insights
# * Production has the highest employee count which means it has highest resource allocation

# %% [markdown]
# # Average salary distribution across employees

# %%
df['Salary'].describe()
# Out:
# count       311.000000
# mean      69020.684887
# std       25156.636930
# min       45046.000000
# 25%       55501.500000
# 50%       62810.000000
# 75%       72036.000000
# max      250000.000000
# Name: Salary, dtype: float64

# %%
df['Salary'].plot(kind='hist')
print("Salary skewness : ", df['Salary'].skew())
# Out:
# Salary skewness :  3.30618080924006

# %% [markdown]
# ### Interpretation
# * Skewness = +3.306- Highly Positively Skewed Distribution
# * Presence of extreme high value outliers (e.g executives/top roles)
# * Mean will be greater than median due to high salary values

# %% [markdown]
# ### Insights
# * Few employees earn very high salaries
# * Majority earn lower to mid range salaries
# * It helps HR to understand the pay structure

# %% [markdown]
# # Does salary impact attrition?

# %%
df.groupby('EmploymentStatus')['Salary'].mean()
# Out:
# EmploymentStatus
# Active                    70694.033816
# Terminated for Cause      75264.875000
# Voluntarily Terminated    63949.204545
# Name: Salary, dtype: float64

# %% [markdown]
# ### Interpretation
# * Employees who left voluntarily have lowest average salary (-63k)
# * Active employees earn moderate salary (-70k)
# * Employees terminated for cause have highest salary (-75k)

# %% [markdown]
# ### Insights
# * Lower salary may be reason for voluntary attrition
# * Employees leaving by choice might be underpaid or looking for better opportunites

# %% [markdown]
# #  Department with highest attrition rate

# %%
pd.crosstab(df['Department'], df['EmploymentStatus'], normalize='index') * 100
# Out:
# EmploymentStatus          Active  Terminated for Cause  Voluntarily Terminated
# Department
# Admin Offices          77.777778             11.111111               11.111111
# Executive Office      100.000000              0.000000                0.000000
# IT/IS                  80.000000              8.000000               12.000000
# Production             60.287081              3.827751               35.885167
# Sales                  83.870968              6.451613                9.677419
# Software Engineering   63.636364              9.090909               27.272727

# %% [markdown]
# ### Interpretation
# * Each row shows % distribution of employee status within a department
# * Helps identify which department have higher attrition
# * Voluntary termination indicated employees leaving by choice

# %% [markdown]
# # Insights
# * Production has highest attrition (~36%) - major concern
# * Software Engineering also show high exits (~27%) - competitive job market
# * Executive and Sales are stable
# * Voluntary attrition is higher than termination

# %% [markdown]
# # Relationship between age and salary

# %%
# Since we do not have any age column we need to create a new column

df['DOB'] = pd.to_datetime(df['DOB'])
df['Age'] = (pd.to_datetime('today') - df['DOB']). dt.days // 365

# %%
df.plot(x='Age', y='Salary', kind='scatter')
df [['Age', 'Salary']].corr()
# Out:
#              Age    Salary
# Age     1.000000 -0.044296
# Salary -0.044296  1.000000

# %% [markdown]
# ### Interpretation
# * Scatter plot shows no clear upward or downward trend between Age and Salary
# * Correlation value is -0.44 ~almost zero(very weak relationship)
# * Salary is spread across all age groups, not dependent on age
# * Presence of ouliers (very high salaries) in different age ranges

# %% [markdown]
# ### Insights
# * Age does not significantly impact salary in this dataset
# * Salary is likely driven by other factors (role, experience, department)
# * Both younger and older employees can earn similar salary ranges
# * A few high earners exist

# %% [markdown]
# # Does work-life balance affect attrition?

# %%
pd.crosstab(df['EmpSatisfaction'], df['EmploymentStatus'], normalize='index') *100
# Out:
# EmploymentStatus      Active  Terminated for Cause  Voluntarily Terminated
# EmpSatisfaction
# 1                 100.000000              0.000000                0.000000
# 2                  55.555556             11.111111               33.333333
# 3                  69.444444              4.629630               25.925926
# 4                  59.574468              6.382979               34.042553
# 5                  70.408163              4.081633               25.510204

# %% [markdown]
# ### Interpretation
# * Table shows % distribution of employment status across satisfaction level (1-5)
# * Lower satisfaction levels (2 & 4) show higher voluntary attrition (~33-34%)
# * Higher satisfaction (3 & 5) shows better retention (~69-70% active)
# * Satisfaction level 1 shows 100% active (likely very few records)

# %% [markdown]
# ### Insights
# * Satisfaction level 2 & 4 have highest voluntary exits (~33-34%)
# * Even high satisfaction (5) has ~25%attrition not fully protective
# * Satisfaction impacts attrition, but not the only factor

# %% [markdown]
# # Jobs having highest salaries

# %%
df.groupby ('Department')['Salary'].mean().sort_values(ascending=False)
# Out:
# Department
# Executive Office        250000.000000
# IT/IS                    97064.640000
# Software Engineering     94989.454545
# Admin Offices            71791.888889
# Sales                    69061.258065
# Production               59953.545455
# Name: Salary, dtype: float64

# %% [markdown]
# ### Insights
# * Executive Office are highest paid
# * IT/IS offer higher salaries than non-tech roles
# * Production roles are lowest paid
# * Salary distribution reflects skill level & job complexity
